# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('df.csv', encoding='euc-kr')
data
# Out:
#              회사명  거래소코드     회계년도     산업코드                 산업명  \
# 0       (주)CMG제약  58820  2001/12  32102.0    의료용 물질 및 의약품 제조업
# 1       (주)CMG제약  58820  2002/12  32102.0    의료용 물질 및 의약품 제조업
# 2       (주)CMG제약  58820  2003/12  32102.0    의료용 물질 및 의약품 제조업
# 3       (주)CMG제약  58820  2004/12  32102.0    의료용 물질 및 의약품 제조업
# 4       (주)CMG제약  58820  2005/12  32102.0    의료용 물질 및 의약품 제조업
# ...          ...    ...      ...      ...                 ...
# 135759   흥아해운(주)   3280  2015/12  85001.0              수상 운송업
# 135760   흥아해운(주)   3280  2020/12  85001.0              수상 운송업
# 135761   흥아해운(주)   3280  2015/12  85001.0              수상 운송업
# 135762   흥아해운(주)   3280  2015/12  85001.0              수상 운송업
# 135763   흥아해운(주)   3280  2019/12  85001.0              수상 운송업
#
#         통계청 한국표준산업분류 코드 10차(대분류)  통계청 한국표준산업분류 코드 10차(중분류)  \
# 0                           21.0                      21.0
# 1                           21.0                      21.0
# 2                           21.0                      21.0
# 3                           21.0                      21.0
# 4                           21.0                      21.0
# ...                          ...                       ...
# 135759                      50.0                      50.0
# 135760                      50.0                      50.0
# 135761                      50.0                      50.0
# 135762                      50.0                      50.0
# 135763                      50.0                      50.0
#
#         통계청 한국표준산업분류 코드 10차(소분류)     회계년월         평가일  업종코드  소속코드         상장일  \
# 0                          212.0      NaN         NaN   1.0   5.0  2001/08/31
# 1                          212.0      NaN         NaN   1.0   5.0  2001/08/31
# 2                          212.0      NaN         NaN   1.0   5.0  2001/08/31
# 3                          212.0      NaN         NaN   1.0   5.0  2001/08/31
# 4                          212.0      NaN         NaN   1.0   5.0  2001/08/31
# ...                          ...      ...         ...   ...   ...         ...
# 135759                     501.0  2015/12  2013/03/29   1.0   1.0  1976/06/29
# 135760                     501.0  2020/12  2018/05/04   1.0   1.0  1976/06/29
# 135761                     501.0  2015/12  2014/03/14   1.0   1.0  1976/06/29
# 135762                     501.0  2015/12  2015/04/09   1.0   1.0  1976/06/29
# 135763                     501.0  2019/12  2014/03/14   1.0   1.0  1976/06/29
#
#        상장폐지일       신용등급 감사의견코드 감사의견
# 0        NaN        NaN     UQ  NaN
# 1        NaN        NaN     UQ  NaN
# 2        NaN        NaN     UQ  NaN
# 3        NaN        NaN     UQ  NaN
# 4        NaN        NaN     UQ  NaN
# ...      ...        ...    ...  ...
# 135759   NaN  BBB-(안정적)     UQ  NaN
# 135760   NaN    BB(부정적)     UQ  NaN
# 135761   NaN  BBB-(안정적)     UQ  NaN
# 135762   NaN  BBB-(안정적)     UQ  NaN
# 135763   NaN  BBB-(안정적)     DU  NaN
#
# [135764 rows x 17 columns]

# %%
data.drop(columns=['산업명'], inplace =True)

# %%
data = data[~data['업종코드'].isnull()]

# %%
data['업종코드'] = data['업종코드'].astype(int)
data['소속코드'] = data['소속코드'].astype(int)
data['산업코드'] = data['산업코드'].astype(int)
# data['기수'] = data['기수'].astype(int)
# Out:
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2612397843.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['업종코드'] = data['업종코드'].astype(int)
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2612397843.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['소속코드'] = data['소속코드'].astype(int)
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2612397843.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['산업코드'] = data['산업코드'].astype(int)

# %%
data['업종코드'] = data['업종코드'].astype(str).str.zfill(2)
data['소속코드'] = data['소속코드'].astype(str).str.zfill(2)
data['산업코드'] = data['산업코드'].astype(str).str.zfill(6)
# Out:
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2806029436.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['업종코드'] = data['업종코드'].astype(str).str.zfill(2)
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2806029436.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['소속코드'] = data['소속코드'].astype(str).str.zfill(2)
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/2806029436.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['산업코드'] = data['산업코드'].astype(str).str.zfill(6)

# %%
data['산업대분류'] = data['산업코드'].str[0:2]
# Out:
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/822201598.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['산업대분류'] = data['산업코드'].str[0:2]

# %%
aaa['감사의견코드'] = bbb['감사의견코드']
aaa
# Out:
#     감사의견코드  감사의견코드 (단위 %)
# UQ    2743          96.93
# DU      23           0.81
# QG      20           0.71
# QS      14           0.49
# QU       9           0.32
# DS       9           0.32
# AG       7           0.25
# NS       5           0.18

# %%
sns.countplot(y=data1['감사의견코드'], data=data1)
plt.ylabel('code')
plt.xlim(0,100)
plt.show()

# %% [markdown]
# ### 데이터 전처리 완료
# ## 부도 데이터 선정

# %%
# DS(감사범위제한 : 감사자료 미비로 감사 범위 제한에 중대한 의문), DU(감사불확실성 : 계속기업가정에 중대한 의문)
sub1 = data.loc[data['감사의견코드'] == "DS"]  
sub2 = data.loc[data['감사의견코드'] == "DU"]

abc = pd.concat([sub1, sub2])

abc.sort_values(by=['회계년도'], ascending=False, inplace=True)
abc.reset_index(inplace = True)
abc.drop(columns='index', inplace =True)
abc['TF'] = abc['회사명'].duplicated()

# %%
df = abc
df['TF'] = df['회사명'].duplicated()
new = df.loc[df['TF']==False]
new2 = df.loc[df['TF']==True]

# %%
print(new['산업대분류'].value_counts())
print(new2['산업대분류'].value_counts())
# Out:
# 03    224
# 10     54
# 07     35
# 06     18
# 13      7
# 14      6
# 16      4
# 18      3
# 08      2
# 01      1
# 02      1
# Name: 산업대분류, dtype: int64
# 03    421
# 06     92
# 10     29
# 02     28
# 07     17
# 08     10
# 13      7
# 14      2
# 18      1
# Name: 산업대분류, dtype: int64

# %%
plt.subplot(121)
sns.countplot(x=new['산업대분류'], data=new)
plt.grid(axis='y', alpha=.5)
plt.xlabel('industrial code')
plt.ylabel('count')
plt.ylim(0,450)
plt.suptitle('from TS2000')
plt.title('unique firm')
plt.subplot(122)
sns.countplot(x=new2['산업대분류'], data=new2)
plt.grid(axis='y', alpha=.5)
plt.xlabel('industrial code')
plt.ylabel('count')
plt.ylim(0,450)
plt.title('duplicated firm')
plt.show()

# %%
print(new['소속코드'].value_counts())
print(new2['소속코드'].value_counts())
# Out:
# 04    293
# 06     42
# 01     11
# 03      5
# 05      4
# Name: 소속코드, dtype: int64
# 04    529
# 06     55
# 01     21
# 03      2
# Name: 소속코드, dtype: int64

# %%
plt.suptitle('belong code of firm')

plt.subplot(121)
sns.countplot(x=new['소속코드'], data=new)
plt.grid(axis='y', alpha=.5)
plt.xlabel('belong code of unique firm')
plt.title('unique firm')
plt.ylim(0,550)

plt.subplot(122)
sns.countplot(x=new2['소속코드'], data=new2)
plt.grid(axis='y', alpha=.5)
plt.xlabel('belong code of duplicated firm')
plt.title('duplicated firm')
plt.ylim(0,550)
plt.show()

# %% [markdown]
# ## 결론
#
# 부도기업의 정의를 DS, DU받은 기업 중 소속코드가 04, 06, 03인 기업을 대상으로 한다.

# %%
# abc 데이터에는 DS, DU를 받은 기업만 있기 때문에, 산업 대분류만 선택하여 추출한다.
# 산업대분류 03(제조업) ,10(출판업), 07(도소매업) 추출
sub1 = data.loc[data['감사의견코드'] == "DS"]  
sub2 = data.loc[data['감사의견코드'] == "DU"]

abc = pd.concat([sub1, sub2])

abc.reset_index(inplace=True)
abc.drop(columns='index', inplace = True)
abc.sort_values(by=['평가일','회계년월','신용등급'],ascending=False, inplace=True)
abc.reset_index(inplace = True)
abc.drop(columns='index', inplace =True)

a1 = abc.loc[abc['소속코드'] == '04']
a2 = abc.loc[abc['소속코드'] == '06']
a3 = abc.loc[abc['소속코드'] == '03']
total1 = pd.concat([a1,a2,a3])

b1 = total1.loc[total1['산업대분류'] == '03'] 
b2 = total1.loc[total1['산업대분류'] == '10']
b3 = total1.loc[total1['산업대분류'] == '07']

total = pd.concat([b1, b2, b3])

v1 = pd.DataFrame(total['감사의견코드'].value_counts())
v2 = pd.DataFrame(total['산업대분류'].value_counts())
v3 = pd.DataFrame(total['소속코드'].value_counts())

total['TF'] = total['회사명'].duplicated()

# %%
v1
# Out:
#     감사의견코드
# DU     394
# DS     361

# %%
v2
# Out:
#     산업대분류
# 03    623
# 10     81
# 07     51

# %%
v3
# Out:
#     소속코드
# 04   657
# 06    92
# 03     6

# %%
total.sort_values(by=['평가일','회계년월','신용등급'],ascending=False, inplace=True)
total.reset_index(inplace = True)
total.drop(columns='index', inplace =True)
total.head(5)
# Out:
#              회사명   거래소코드     회계년도    산업코드     회계년월         평가일 업종코드 소속코드  \
# 0          (주)샘코  263540  2020/12  033103  2020/12  2020/09/14   01   06
# 1   (주)아이티엑스에이아이   99520  2020/12  032605  2020/12  2020/05/13   01   06
# 2  (주)온코퀘스트파마슈티컬   78590  2020/12  033003  2020/12  2020/04/23   01   06
# 3        현진소재(주)   53660  2020/12  032509  2020/12  2020/02/20   01   06
# 4        현진소재(주)   53660  2019/12  032509  2019/12  2020/02/20   01   06
#
#           상장일 상장폐지일 신용등급 감사의견코드 감사의견 산업대분류     TF
# 0  2017/09/15   NaN   B-     DU  NaN    03  False
# 1  2009/12/22   NaN   BB     DS  NaN    03  False
# 2  2005/10/27   NaN  BB0     DU  NaN    03  False
# 3  2002/02/15   NaN  CCC     DU  NaN    03  False
# 4  2002/02/15   NaN  CCC     DU  NaN    03   True

# %%
unique_firm = total.loc[total['TF']==False]
duplicated_firm = total.loc[total['TF']==True]

# %%
v1 = pd.DataFrame(unique_firm['산업대분류'].value_counts())
v2 = pd.DataFrame(duplicated_firm['산업대분류'].value_counts())

# %%
v1
# Out:
#     산업대분류
# 03    214
# 10     52
# 07     34

# %%
v2
# Out:
#     산업대분류
# 03    409
# 10     29
# 07     17

# %%
plt.subplot(121)
sns.countplot(x=unique_firm['산업대분류'], data=unique_firm)
plt.grid(axis='y', alpha=.5)
plt.xlabel('industrial code')
plt.ylabel('count')
plt.ylim(0,450)
plt.suptitle('from TS2000')
plt.title('unique firm')
plt.subplot(122)
sns.countplot(x=duplicated_firm['산업대분류'], data=duplicated_firm)
plt.grid(axis='y', alpha=.5)
plt.xlabel('industrial code')
plt.ylabel('count')
plt.ylim(0,450)
plt.title('duplicated firm')
plt.show()

# %%
v1 = pd.DataFrame(unique_firm['소속코드'].value_counts())
v2 = pd.DataFrame(duplicated_firm['소속코드'].value_counts())

# %%
v1
# Out:
#     소속코드
# 04   257
# 06    39
# 03     4

# %%
v2
# Out:
#     소속코드
# 04   400
# 06    53
# 03     2

# %%
plt.suptitle('belong code of firm')

plt.subplot(121)
sns.countplot(x=unique_firm['소속코드'], data=unique_firm)
plt.grid(axis='y', alpha=.5)
plt.xlabel('belong code of unique firm')
plt.title('unique firm')
plt.ylim(0,410)

plt.subplot(122)
sns.countplot(x=duplicated_firm['소속코드'], data=duplicated_firm)
plt.grid(axis='y', alpha=.5)
plt.xlabel('belong code of duplicated firm')
plt.title('duplicated firm')
plt.ylim(0,410)
plt.show()

# %%
# aaa =total.loc[total['회사명'] == 'STX조선해양(주)']
# aaa.loc[aaa['TF']==False]
# aaa.sort_values(by=['평가일','회계년월','신용등급'], ascending=False).head(30)

# %%
unique_firm.reset_index(inplace=True)
unique_firm.drop(columns= {'TF','index'}, inplace=True)
unique_firm
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                회사명   거래소코드     회계년도    산업코드     회계년월         평가일 업종코드 소속코드  \
# 0            (주)샘코  263540  2020/12  033103  2020/12  2020/09/14   01   06
# 1     (주)아이티엑스에이아이   99520  2020/12  032605  2020/12  2020/05/13   01   06
# 2    (주)온코퀘스트파마슈티컬   78590  2020/12  033003  2020/12  2020/04/23   01   06
# 3          현진소재(주)   53660  2020/12  032509  2020/12  2020/02/20   01   06
# 4           (주)이큐셀  160600  2019/12  032902  2019/12  2019/09/26   01   06
# ..             ...     ...      ...     ...      ...         ...  ...  ...
# 295         아래스(주)   50320  2018/12  074605      NaN         NaN   01   06
# 296      애머릿지코퍼레이션  900100  2019/12  074502      NaN         NaN   01   06
# 297     지스마트글로벌(주)  114570  2019/12  074608      NaN         NaN   01   06
# 298       파나케이아(주)   58530  2020/12  074604      NaN         NaN   01   06
# 299     (주)폴루스바이오팜    7630  2020/12  074601      NaN         NaN   01   03
#
#             상장일 상장폐지일 신용등급 감사의견코드 감사의견 산업대분류
# 0    2017/09/15   NaN   B-     DU  NaN    03
# 1    2009/12/22   NaN   BB     DS  NaN    03
# 2    2005/10/27   NaN  BB0     DU  NaN    03
# 3    2002/02/15   NaN  CCC     DU  NaN    03
# 4    2015/06/26   NaN  BBB     DU  NaN    03
# ..          ...   ...  ...    ...  ...   ...
# 295  2002/01/15   NaN  NaN     DU  NaN    07
# 296  2010/04/21   NaN  NaN     DU  NaN    07
# 297  2010/02/04   NaN  NaN     DU  NaN    07
# 298  2002/02/05   NaN  NaN     DU  NaN    07
# 299  1988/10/24   NaN  NaN     DU  NaN    07
#
# [300 rows x 14 columns]

# %%
unique_firm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   회사명     300 non-null    object
#  1   거래소코드   300 non-null    int64
#  2   회계년도    300 non-null    object
#  3   산업코드    300 non-null    object
#  4   회계년월    81 non-null     object
#  5   평가일     81 non-null     object
#  6   업종코드    300 non-null    object
#  7   소속코드    300 non-null    object
#  8   상장일     300 non-null    object
#  9   상장폐지일   257 non-null    object
#  10  신용등급    81 non-null     object
#  11  감사의견코드  300 non-null    object
#  12  감사의견    230 non-null    object
#  13  산업대분류   300 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 32.9+ KB

# %%
unique_firm['회계년도_new'] = unique_firm['회계년도'].str[0:4]
# Out:
# /var/folders/1v/ctxpzb994v98h43xyk972tmc0000gn/T/ipykernel_32615/4224594153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_firm['회계년도_new'] = unique_firm['회계년도'].str[0:4]

# %%
unique_firm.sort_values(by=['회계년도_new'], ascending=False, inplace = True)

sns.countplot(y=unique_firm['회계년도_new'], data=unique_firm)
plt.ylabel('Account_year')
plt.title('bankrupcy firm sorted by Account year')
plt.grid(axis='x', alpha = .5)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
aa1 = pd.DataFrame(unique_firm['회계년도_new'].value_counts())
aa1
# Out:
#       회계년도_new
# 2009        41
# 2008        27
# 2020        26
# 2003        20
# 2011        18
# 2004        18
# 2019        18
# 2010        17
# 2017        16
# 2012        14
# 2013        12
# 2018        12
# 2000        12
# 2007        11
# 2001         8
# 2015         6
# 2002         6
# 2014         5
# 2016         5
# 2005         5
# 2006         3

# %%
unique_firm.to_csv('unique_firm.csv')
